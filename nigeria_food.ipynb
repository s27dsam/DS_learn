# %% [markdown]
# <a href="https://colab.research.google.com/github/s27dsam/DS_learn/blob/main/nigeria_food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('/content/sample_data/food-prices-for-nigeria-2017-2021.csv')

# %%
data
# Out:
#                                    ItemLabels  ...  Year-on-Year
# 0                      Agric eggs medium size  ...         27.31
# 1        Agric eggs(medium size price of one)  ...         28.15
# 2                      Beans brown,sold loose  ...         46.47
# 3           Beans:white black eye. sold loose  ...         54.61
# 4                                Beef Bone in  ...         26.37
# 5                               Beef,boneless  ...         30.01
# 6                           Bread sliced 500g  ...         23.04
# 7                         Bread unsliced 500g  ...         19.36
# 8                         Broken Rice (Ofada)  ...          3.91
# 9                      Catfish (obokun) fresh  ...         19.74
# 10                             Catfish :dried  ...         12.80
# 11                             Catfish Smoked  ...          8.28
# 12                               Chicken Feet  ...         21.07
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of                                    ItemLabels  ...  Year-on-Year
# 0                      Agric eggs medium size  ...         27.31
# 1        Agric eggs(medium size price of one)  ...         28.15
# 2                      Beans brown,sold loose  ...         46.47
# 3           Beans:white black eye. sold loose  ...         54.61
# 4                                Beef Bone in  ...         26.37
# 5                               Beef,boneless  ...         30.01
# 6                           Bread sliced 500g  ...         23.04
# 7                         Bread unsliced 500g  ...         19.36
# 8                         Broken Rice (Ofada)  ...          3.91
# 9                      Catfish (obokun) fresh  ...         19.74
# 10                             Catfish :dried  ...         12.80
# 11                             Catfish Smoked  ...          8.28
# 12                               Chicken Feet  ...         21.07
# ...

# %%
data.describe()
# Out:
#             Jan-17       Feb-17  ...  Month-on-Month  Year-on-Year
# count    43.000000    43.000000  ...       43.000000     43.000000
# mean    594.680233   604.477442  ...        3.181395     22.144419
# std     505.317539   512.329082  ...        2.372729     12.982093
# min      47.420000    42.900000  ...       -1.190000    -10.120000
# 25%     251.690000   245.945000  ...        2.145000     12.280000
# 50%     377.410000   392.040000  ...        2.560000     21.820000
# 75%     850.955000   855.240000  ...        3.335000     28.220000
# max    2204.120000  2150.180000  ...       11.410000     54.610000
#
# [8 rows x 61 columns]

# %%
data.columns
# Out:
# Index(['ItemLabels', 'Jan-17', 'Feb-17', 'Mar-17', 'Apr-17', 'May-17',
#        'Jun-17', 'Jul-17', 'Aug-17', 'Sep-17', 'Oct-17', 'Nov-17', 'Dec-17',
#        'Jan-18', 'Feb-18', 'Mar-18', 'Apr-18', 'May-18', 'Jun-18', 'Jul-18',
#        'Aug-18', 'Sep-18', 'Oct-18', 'Nov-18', 'Dec-18', 'Jan-19', 'Feb-19',
#        'Mar-19', 'Apr-19', 'May-19', 'Jun-19', 'Jul-19', 'Aug-19', 'Sep-19',
#        'Oct-19', 'Nov-19', 'Dec-19', 'Jan-20', 'Feb-20', 'Mar-20', 'Apr-20',
#        'May-20', 'Jun-20', 'Jul-20', 'Aug-20', 'Sep-20', 'Oct-20', 'Nov-20',
#        'Dec-20', 'Jan-21', 'Feb-21', 'Mar-21', 'Apr-21', 'May-21', 'Jun-21',
#        'Jul-21', 'Aug-21', 'Sep-21', 'Oct-21', 'Nov-21', 'Lowest', 'Highest',
#        'Month-on-Month', 'Year-on-Year'],
#       dtype='object')

# %%
data.shape
# Out:
# (45, 64)

# %%
data.isnull().sum()
# Out:
# ItemLabels        1
# Jan-17            2
# Feb-17            2
# Mar-17            2
# Apr-17            2
#                  ..
# Nov-21            2
# Lowest            2
# Highest           2
# Month-on-Month    2
# Year-on-Year      2
# Length: 64, dtype: int64

# %%
data['Year-on-Year'].describe()
# Out:
# count    43.000000
# mean     22.144419
# std      12.982093
# min     -10.120000
# 25%      12.280000
# 50%      21.820000
# 75%      28.220000
# max      54.610000
# Name: Year-on-Year, dtype: float64

# %%
#histogram
sns.distplot(data['Year-on-Year']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
plt.scatter(data['Jan-17'],data['Nov-21'])
